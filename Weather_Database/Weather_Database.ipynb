# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create random latitude and longitude combinations.
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list.
coordinates=list(lat_lngs)

# %%
# Import the citypy
from citipy import citipy

# %%
# Create a list for the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Base url for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint url for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 49.96,
#   'feels_like': 46.72,
#   'temp_min': 45.88,
#   'temp_max': 53.44,
#   'pressure': 1019,
#   'humidity': 83},
#  'visibility': 10000,
#  'wind': {'speed': 8.01, 'deg': 355, 'gust': 15.01},
#  'clouds': {'all': 36},
#  'dt': 1633056264,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1632998420,
#   'sunset': 1633040867},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create and empty list to hold the weather data.
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count=1
set_count=1

# Loop through all the cities in the city list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
    # Create endpoint url with each city.
    city_url= url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather=requests.get(city_url).json()
        # Parse out the needed data.
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity=city_weather["main"]["humidity"]
        city_clouds=city_weather["clouds"]["all"]
        city_wind=city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        city_country=city_weather["sys"]["country"]      
        
        # Append the city information into city_data list.
        city_data.append({"City":city.title(), "Country":city_country, "Lat": city_lat, "Lng":city_lng, "Max Temp":city_max_temp, "Humidity":city_humidity, "Cloudiness":city_clouds, "Wind Speed":city_wind, "Description":city_description})
    except:
        print("City not found. Skipping...")
        pass
# Indicate that the data loading is done.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | turbat
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | sambava
# Processing Record 4 of Set 1 | kenai
# Processing Record 5 of Set 1 | nouadhibou
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | zaltan
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | pakpattan
# Processing Record 17 of Set 1 | nome
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | sept-iles
# Processing Record 20 of Set 1 | ballina
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | uusikaupunki
# Processing Record 23 of Set 1 | isla vista
# Processing Record 24 of Set 1 | bilma
# Processing Record 25 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 26 of Set 1 | luneburg
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | mirnyy
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | paamiut
# Processing Record 37 of Set 1 | vokhma
# Processing Record 38 of Set 1 | hobyo
# Processing Record 39 of Set 1 | manthani
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | laguna
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | zhezkazgan
# Processing Record 45 of Set 1 | shimoda
# Processing Record 46 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 1 | sinjah
# City not found. Skipping...
# Processing Record 48 of Set 1 | snasa
# Processing Record 49 of Set 1 | goundam
# Processing Record 50 of Set 1 | mont-de-marsan
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | broome
# Processing Record 3 of Set 2 | los llanos de aridane
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | westport
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | yulara
# Processing Record 9 of Set 2 | husavik
# Processing Record 10 of Set 2 | pokaran
# Processing Record 11 of Set 2 | talara
# Processing Record 12 of Set 2 | port hardy
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | willowmore
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | kosa
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | yumen
# Processing Record 21 of Set 2 | vostok
# Processing Record 22 of Set 2 | vao
# Processing Record 23 of Set 2 | farafangana
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | alghero
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | aykhal
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | saravan
# Processing Record 32 of Set 2 | derzhavinsk
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | hazorasp
# Processing Record 35 of Set 2 | lida
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | rikitea
# Processing Record 38 of Set 2 | strezhevoy
# Processing Record 39 of Set 2 | manacapuru
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | beian
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | lokosovo
# Processing Record 44 of Set 2 | jalu
# Processing Record 45 of Set 2 | matara
# Processing Record 46 of Set 2 | ketchikan
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | sobolevo
# Processing Record 50 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | fairbanks
# Processing Record 4 of Set 3 | udachnyy
# Processing Record 5 of Set 3 | san joaquin
# Processing Record 6 of Set 3 | puerto palomas
# Processing Record 7 of Set 3 | morvi
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | san policarpo
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | sorland
# Processing Record 14 of Set 3 | kudat
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | lasa
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | nerl
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | kabanjahe
# Processing Record 22 of Set 3 | listowel
# Processing Record 23 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 3 | catazaja
# Processing Record 25 of Set 3 | mocuba
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | khandyga
# Processing Record 29 of Set 3 | kanigoro
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | dingle
# Processing Record 33 of Set 3 | tres arroyos
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | deputatskiy
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | gaogou
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | charters towers
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | lima
# Processing Record 43 of Set 3 | mount isa
# Processing Record 44 of Set 3 | bafq
# Processing Record 45 of Set 3 | pangnirtung
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | port hawkesbury
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 50 of Set 3 | cravo norte
# Processing Record 1 of Set 4 | luderitz
# Processing Record 2 of Set 4 | asau
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | marmora
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | pergine valsugana
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | gat
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | college
# Processing Record 14 of Set 4 | san jose
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | kasamwa
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | anloga
# Processing Record 20 of Set 4 | rocha
# Processing Record 21 of Set 4 | bluff
# Processing Record 22 of Set 4 | boa vista
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | alugan
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | concepcion tutuapa
# Processing Record 27 of Set 4 | kiruna
# Processing Record 28 of Set 4 | prince rupert
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | nantucket
# Processing Record 31 of Set 4 | katangli
# Processing Record 32 of Set 4 | puerto suarez
# Processing Record 33 of Set 4 | louis trichardt
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | pozo colorado
# Processing Record 36 of Set 4 | moose factory
# Processing Record 37 of Set 4 | san roque
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | jam sahib
# Processing Record 40 of Set 4 | hamilton
# Processing Record 41 of Set 4 | narasannapeta
# Processing Record 42 of Set 4 | yar-sale
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | lethem
# Processing Record 45 of Set 4 | soe
# Processing Record 46 of Set 4 | seoul
# Processing Record 47 of Set 4 | kropotkin
# Processing Record 48 of Set 4 | bushtyno
# Processing Record 49 of Set 4 | sinnamary
# Processing Record 50 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 5 | soyo
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | darlowo
# Processing Record 4 of Set 5 | ilulissat
# Processing Record 5 of Set 5 | cape town
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | kutum
# Processing Record 8 of Set 5 | kerrville
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | toora-khem
# Processing Record 14 of Set 5 | fare
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | poum
# Processing Record 17 of Set 5 | mogadishu
# Processing Record 18 of Set 5 | teknaf
# Processing Record 19 of Set 5 | borisoglebskiy
# Processing Record 20 of Set 5 | waipawa
# Processing Record 21 of Set 5 | mukhen
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | punuare
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | indramayu
# Processing Record 27 of Set 5 | ambon
# Processing Record 28 of Set 5 | limbang
# Processing Record 29 of Set 5 | dubrovka
# Processing Record 30 of Set 5 | meadow lake
# Processing Record 31 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | vale da amoreira
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | tuatapere
# Processing Record 36 of Set 5 | zeya
# Processing Record 37 of Set 5 | rio gallegos
# Processing Record 38 of Set 5 | vila
# Processing Record 39 of Set 5 | el tigre
# Processing Record 40 of Set 5 | sawakin
# Processing Record 41 of Set 5 | la sierra
# Processing Record 42 of Set 5 | yakeshi
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | gashua
# Processing Record 45 of Set 5 | san juan
# Processing Record 46 of Set 5 | mogocha
# Processing Record 47 of Set 5 | kungsbacka
# Processing Record 48 of Set 5 | necochea
# Processing Record 49 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 5 | itarema
# Processing Record 1 of Set 6 | kozlovo
# Processing Record 2 of Set 6 | sakakah
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 5 of Set 6 | havre
# Processing Record 6 of Set 6 | chifeng
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | san jeronimo
# Processing Record 9 of Set 6 | surt
# Processing Record 10 of Set 6 | henties bay
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | fairhope
# Processing Record 13 of Set 6 | chicxulub
# Processing Record 14 of Set 6 | taoudenni
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | clayton
# Processing Record 17 of Set 6 | amazar
# Processing Record 18 of Set 6 | biak
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | trinidad
# Processing Record 21 of Set 6 | jinchang
# Processing Record 22 of Set 6 | dire
# Processing Record 23 of Set 6 | zhob
# Processing Record 24 of Set 6 | gravdal
# Processing Record 25 of Set 6 | port alfred
# Processing Record 26 of Set 6 | rio cuarto
# Processing Record 27 of Set 6 | brigantine
# Processing Record 28 of Set 6 | buraydah
# Processing Record 29 of Set 6 | adilcevaz
# Processing Record 30 of Set 6 | caucaia
# Processing Record 31 of Set 6 | kidal
# Processing Record 32 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 6 | nuristan
# Processing Record 34 of Set 6 | kushmurun
# Processing Record 35 of Set 6 | washington
# Processing Record 36 of Set 6 | new smyrna beach
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | sainte-suzanne
# Processing Record 39 of Set 6 | basco
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | qixingtai
# Processing Record 42 of Set 6 | lamu
# Processing Record 43 of Set 6 | bolshaya sosnova
# Processing Record 44 of Set 6 | collie
# Processing Record 45 of Set 6 | egvekinot
# Processing Record 46 of Set 6 | norsup
# Processing Record 47 of Set 6 | marsa matruh
# Processing Record 48 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 6 | sault sainte marie
# Processing Record 50 of Set 6 | ahtopol
# Processing Record 1 of Set 7 | tecoanapa
# Processing Record 2 of Set 7 | saint-georges
# Processing Record 3 of Set 7 | aswan
# Processing Record 4 of Set 7 | kozhva
# Processing Record 5 of Set 7 | sinjar
# Processing Record 6 of Set 7 | mountain home
# Processing Record 7 of Set 7 | sabang
# Processing Record 8 of Set 7 | thonon-les-bains
# Processing Record 9 of Set 7 | ambulu
# Processing Record 10 of Set 7 | muros
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | mana
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | san pedro
# Processing Record 15 of Set 7 | karratha
# Processing Record 16 of Set 7 | salalah
# Processing Record 17 of Set 7 | alta floresta
# Processing Record 18 of Set 7 | kahului
# Processing Record 19 of Set 7 | joshimath
# Processing Record 20 of Set 7 | wewak
# Processing Record 21 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 7 | thompson
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 7 | jasper
# Processing Record 26 of Set 7 | souillac
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | beloha
# Processing Record 29 of Set 7 | houma
# Processing Record 30 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | roma
# Processing Record 34 of Set 7 | smithers
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | valdivia
# Processing Record 37 of Set 7 | graham
# Processing Record 38 of Set 7 | russell
# Processing Record 39 of Set 7 | leningradskiy
# Processing Record 40 of Set 7 | swan hill
# Processing Record 41 of Set 7 | oda
# Processing Record 42 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 7 | pepel
# Processing Record 44 of Set 7 | jinxiang
# Processing Record 45 of Set 7 | tual
# Processing Record 46 of Set 7 | giresun
# Processing Record 47 of Set 7 | gobabis
# Processing Record 48 of Set 7 | chernyshevskiy
# Processing Record 49 of Set 7 | bayan
# Processing Record 50 of Set 7 | turukhansk
# Processing Record 1 of Set 8 | san mateo del mar
# Processing Record 2 of Set 8 | padang
# Processing Record 3 of Set 8 | shelburne
# Processing Record 4 of Set 8 | katherine
# Processing Record 5 of Set 8 | jamsa
# Processing Record 6 of Set 8 | texarkana
# Processing Record 7 of Set 8 | port augusta
# Processing Record 8 of Set 8 | ulladulla
# Processing Record 9 of Set 8 | humberto de campos
# Processing Record 10 of Set 8 | bougouni
# Processing Record 11 of Set 8 | grajau
# Processing Record 12 of Set 8 | cap malheureux
# Processing Record 13 of Set 8 | fenwick
# Processing Record 14 of Set 8 | lodja
# Processing Record 15 of Set 8 | selenginsk
# Processing Record 16 of Set 8 | marquette
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 8 | ialibu
# Processing Record 20 of Set 8 | ruidoso
# Processing Record 21 of Set 8 | elizabeth city
# Processing Record 22 of Set 8 | usinsk
# Processing Record 23 of Set 8 | celestun
# Processing Record 24 of Set 8 | ostrovnoy
# Processing Record 25 of Set 8 | narsaq
# Processing Record 26 of Set 8 | nenjiang
# Processing Record 27 of Set 8 | piedras negras
# Processing Record 28 of Set 8 | clyde river
# Processing Record 29 of Set 8 | manadhoo
# Processing Record 30 of Set 8 | markova
# Processing Record 31 of Set 8 | bischwiller
# Processing Record 32 of Set 8 | cap-chat
# Processing Record 33 of Set 8 | paracuru
# Processing Record 34 of Set 8 | ko samui
# Processing Record 35 of Set 8 | noyabrsk
# Processing Record 36 of Set 8 | nishihara
# Processing Record 37 of Set 8 | virginia beach
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | biltine
# Processing Record 40 of Set 8 | menongue
# Processing Record 41 of Set 8 | murchison
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | mbanza-ngungu
# Processing Record 44 of Set 8 | caravelas
# Processing Record 45 of Set 8 | octeville
# Processing Record 46 of Set 8 | talavera
# Processing Record 47 of Set 8 | poya
# Processing Record 48 of Set 8 | athabasca
# Processing Record 49 of Set 8 | mujiayingzi
# Processing Record 50 of Set 8 | finschhafen
# Processing Record 1 of Set 9 | pennsville
# Processing Record 2 of Set 9 | cururupu
# Processing Record 3 of Set 9 | bela
# Processing Record 4 of Set 9 | odienne
# Processing Record 5 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 6 of Set 9 | sonari
# Processing Record 7 of Set 9 | mogwase
# Processing Record 8 of Set 9 | provideniya
# Processing Record 9 of Set 9 | jadu
# Processing Record 10 of Set 9 | dudinka
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | antofagasta
# Processing Record 13 of Set 9 | hailar
# Processing Record 14 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 9 | nisia floresta
# Processing Record 16 of Set 9 | sumbe
# Processing Record 17 of Set 9 | vanino
# Processing Record 18 of Set 9 | la paz centro
# Processing Record 19 of Set 9 | harper
# Processing Record 20 of Set 9 | bac lieu
# Processing Record 21 of Set 9 | old town
# Processing Record 22 of Set 9 | ust-maya
# Processing Record 23 of Set 9 | walvis bay
# Processing Record 24 of Set 9 | stabat
# Processing Record 25 of Set 9 | tungor
# Processing Record 26 of Set 9 | marmashen
# Processing Record 27 of Set 9 | burley
# Processing Record 28 of Set 9 | tallahassee
# Processing Record 29 of Set 9 | muzquiz
# City not found. Skipping...
# Processing Record 30 of Set 9 | ibra
# Processing Record 31 of Set 9 | santa fe
# Processing Record 32 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 9 | casablanca
# Processing Record 34 of Set 9 | karlstad
# Processing Record 35 of Set 9 | price
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | verkhnevilyuysk
# Processing Record 38 of Set 9 | baruun-urt
# Processing Record 39 of Set 9 | shelopugino
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | katsina
# Processing Record 42 of Set 9 | methoni
# Processing Record 43 of Set 9 | nabire
# Processing Record 44 of Set 9 | mehamn
# Processing Record 45 of Set 9 | oyama
# Processing Record 46 of Set 9 | vardo
# Processing Record 47 of Set 9 | menomonie
# Processing Record 48 of Set 9 | verkh-tula
# Processing Record 49 of Set 9 | nicoya
# Processing Record 50 of Set 9 | corbelia
# Processing Record 1 of Set 10 | ponta do sol
# Processing Record 2 of Set 10 | pulandian
# Processing Record 3 of Set 10 | lady lake
# Processing Record 4 of Set 10 | grand-santi
# Processing Record 5 of Set 10 | dryden
# Processing Record 6 of Set 10 | kolondieba
# Processing Record 7 of Set 10 | tezu
# Processing Record 8 of Set 10 | bubaque
# Processing Record 9 of Set 10 | zavitinsk
# Processing Record 10 of Set 10 | majene
# Processing Record 11 of Set 10 | dingzhou
# Processing Record 12 of Set 10 | goderich
# Processing Record 13 of Set 10 | lockhart
# Processing Record 14 of Set 10 | jiujiang
# Processing Record 15 of Set 10 | mangrol
# Processing Record 16 of Set 10 | ondjiva
# Processing Record 17 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 10 | domoni
# Processing Record 19 of Set 10 | uarini
# Processing Record 20 of Set 10 | san ramon
# Processing Record 21 of Set 10 | mendoza
# Processing Record 22 of Set 10 | kristiansund
# Processing Record 23 of Set 10 | coro
# Processing Record 24 of Set 10 | usogorsk
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | deer lake
# Processing Record 27 of Set 10 | srednekolymsk
# Processing Record 28 of Set 10 | kota belud
# Processing Record 29 of Set 10 | mangan
# Processing Record 30 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 10 | constitucion
# Processing Record 32 of Set 10 | palmer
# Processing Record 33 of Set 10 | yelizovo
# Processing Record 34 of Set 10 | lorengau
# Processing Record 35 of Set 10 | kihei
# Processing Record 36 of Set 10 | tanabe
# Processing Record 37 of Set 10 | zamora
# Processing Record 38 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | sal rei
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | severnoye
# Processing Record 43 of Set 10 | yeniseysk
# Processing Record 44 of Set 10 | malvern
# Processing Record 45 of Set 10 | anqing
# Processing Record 46 of Set 10 | manokwari
# Processing Record 47 of Set 10 | cerchezu
# Processing Record 48 of Set 10 | ararangua
# Processing Record 49 of Set 10 | umm lajj
# Processing Record 50 of Set 10 | winnemucca
# Processing Record 1 of Set 11 | namibe
# Processing Record 2 of Set 11 | sur
# Processing Record 3 of Set 11 | lang son
# Processing Record 4 of Set 11 | borgarnes
# Processing Record 5 of Set 11 | krasnoarmeysk
# Processing Record 6 of Set 11 | pilot butte
# Processing Record 7 of Set 11 | ust-tsilma
# Processing Record 8 of Set 11 | aborlan
# Processing Record 9 of Set 11 | guekedou
# City not found. Skipping...
# Processing Record 10 of Set 11 | nurota
# Processing Record 11 of Set 11 | gorontalo
# Processing Record 12 of Set 11 | burica
# City not found. Skipping...
# Processing Record 13 of Set 11 | kamaishi
# Processing Record 14 of Set 11 | batagay-alyta
# Processing Record 15 of Set 11 | wawa
# Processing Record 16 of Set 11 | muroto
# Processing Record 17 of Set 11 | cah ab
# City not found. Skipping...
# Processing Record 18 of Set 11 | rawson
# Processing Record 19 of Set 11 | moron
# Processing Record 20 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 11 | nyurba
# Processing Record 22 of Set 11 | camacha
# Processing Record 23 of Set 11 | pierre
# Processing Record 24 of Set 11 | somerset east
# Processing Record 25 of Set 11 | olinda
# Processing Record 26 of Set 11 | skegness
# Processing Record 27 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 11 | margate
# Processing Record 29 of Set 11 | nuuk
# Processing Record 30 of Set 11 | wad rawah
# Processing Record 31 of Set 11 | fukue
# Processing Record 32 of Set 11 | mabaruma
# Processing Record 33 of Set 11 | hitoyoshi
# Processing Record 34 of Set 11 | ayan
# Processing Record 35 of Set 11 | dicabisagan
# Processing Record 36 of Set 11 | amahai
# Processing Record 37 of Set 11 | oros
# Processing Record 38 of Set 11 | flinders
# Processing Record 39 of Set 11 | indiaroba
# Processing Record 40 of Set 11 | khuzhir
# Processing Record 41 of Set 11 | akim swedru
# Processing Record 42 of Set 11 | port lincoln
# Processing Record 43 of Set 11 | olafsvik
# Processing Record 44 of Set 11 | viransehir
# Processing Record 45 of Set 11 | roebourne
# Processing Record 46 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 11 | havre-saint-pierre
# Processing Record 48 of Set 11 | cradock
# Processing Record 49 of Set 11 | iqaluit
# Processing Record 50 of Set 11 | witu
# Processing Record 1 of Set 12 | auki
# Processing Record 2 of Set 12 | hermosillo
# Processing Record 3 of Set 12 | puerto plata
# Processing Record 4 of Set 12 | banda aceh
# Processing Record 5 of Set 12 | bogotol
# Processing Record 6 of Set 12 | juquia
# Processing Record 7 of Set 12 | cabedelo
# Processing Record 8 of Set 12 | watertown
# Processing Record 9 of Set 12 | lishu
# Processing Record 10 of Set 12 | nuqui
# Processing Record 11 of Set 12 | atar
# Processing Record 12 of Set 12 | le pradet
# Processing Record 13 of Set 12 | grenaa
# Processing Record 14 of Set 12 | zell am see
# Processing Record 15 of Set 12 | saldanha
# Processing Record 16 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 12 | ginda
# Processing Record 18 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 19 of Set 12 | ixtapa
# Processing Record 20 of Set 12 | aketi
# Processing Record 21 of Set 12 | sayville
# Processing Record 22 of Set 12 | hay river
# Processing Record 23 of Set 12 | ratnagiri
# Processing Record 24 of Set 12 | feijo
# Processing Record 25 of Set 12 | kaiyuan
# Processing Record 26 of Set 12 | rundu
# Processing Record 27 of Set 12 | faya
# Processing Record 28 of Set 12 | villanueva de cordoba
# Processing Record 29 of Set 12 | sioux lookout
# Processing Record 30 of Set 12 | along
# Processing Record 31 of Set 12 | kifri
# Processing Record 32 of Set 12 | basoko
# Processing Record 33 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 34 of Set 12 | terni
# Processing Record 35 of Set 12 | auras
# Processing Record 36 of Set 12 | zhireken
# Processing Record 37 of Set 12 | lakota
# Processing Record 38 of Set 12 | sembakung
# Processing Record 39 of Set 12 | dwarka
# Processing Record 40 of Set 12 | great falls
# Processing Record 41 of Set 12 | yaan
# Processing Record 42 of Set 12 | marienburg
# Processing Record 43 of Set 12 | belyy yar
# Processing Record 44 of Set 12 | sylacauga
# Processing Record 45 of Set 12 | san cristobal
# Processing Record 46 of Set 12 | nador
# Processing Record 47 of Set 12 | karaton
# Processing Record 48 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 12 | cabra
# Processing Record 50 of Set 12 | ahipara
# Processing Record 1 of Set 13 | verkh-usugli
# Processing Record 2 of Set 13 | zlobin
# Processing Record 3 of Set 13 | kapit
# Processing Record 4 of Set 13 | ucluelet
# Processing Record 5 of Set 13 | itigi
# Processing Record 6 of Set 13 | oktyabrskiy
# Processing Record 7 of Set 13 | kavaratti
# Processing Record 8 of Set 13 | aqtobe
# Processing Record 9 of Set 13 | komsomolskiy
# Processing Record 10 of Set 13 | bosaso
# Processing Record 11 of Set 13 | beruwala
# Processing Record 12 of Set 13 | kingisepp
# Processing Record 13 of Set 13 | san rafael
# Processing Record 14 of Set 13 | rosarito
# Processing Record 15 of Set 13 | santa cruz del sur
# Processing Record 16 of Set 13 | progreso
# Processing Record 17 of Set 13 | solnechnyy
# Processing Record 18 of Set 13 | mosquera
# Processing Record 19 of Set 13 | pevek
# Processing Record 20 of Set 13 | kiunga
# Processing Record 21 of Set 13 | pajapan
# Processing Record 22 of Set 13 | zyryanka
# Processing Record 23 of Set 13 | tigil
# Processing Record 24 of Set 13 | kakonko
# Processing Record 25 of Set 13 | tessalit
# Processing Record 26 of Set 13 | saint-leu
# Processing Record 27 of Set 13 | gizo
# Processing Record 28 of Set 13 | araouane
# Processing Record 29 of Set 13 | andenes
# Processing Record 30 of Set 13 | damietta
# Processing Record 31 of Set 13 | conde
# Processing Record 32 of Set 13 | palafrugell
# Processing Record 33 of Set 13 | cuenca
# Processing Record 34 of Set 13 | tiarei
# Processing Record 35 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 13 | khash
# Processing Record 37 of Set 13 | half moon bay
# Processing Record 38 of Set 13 | beisfjord
# Processing Record 39 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | la ciotat
# Processing Record 41 of Set 13 | lincoln
# Processing Record 42 of Set 13 | ginir
# Processing Record 43 of Set 13 | tarata
# Processing Record 44 of Set 13 | yeppoon
# Processing Record 45 of Set 13 | gallup
# Processing Record 46 of Set 13 | otane
# Processing Record 47 of Set 13 | nemuro
# Processing Record 48 of Set 13 | tura
# Processing Record 49 of Set 13 | byron bay
# Processing Record 50 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 14 | fujin
# Processing Record 2 of Set 14 | port-gentil
# Processing Record 3 of Set 14 | balikpapan
# Processing Record 4 of Set 14 | port macquarie
# Processing Record 5 of Set 14 | cidreira
# Processing Record 6 of Set 14 | zemio
# Processing Record 7 of Set 14 | morden
# Processing Record 8 of Set 14 | porto novo
# Processing Record 9 of Set 14 | presidencia roque saenz pena
# Processing Record 10 of Set 14 | itaituba
# Processing Record 11 of Set 14 | tadine
# Processing Record 12 of Set 14 | igrim
# Processing Record 13 of Set 14 | kalmunai
# Processing Record 14 of Set 14 | pafos
# Processing Record 15 of Set 14 | rincon
# Processing Record 16 of Set 14 | ulaangom
# Processing Record 17 of Set 14 | trincomalee
# Processing Record 18 of Set 14 | smirnykh
# Processing Record 19 of Set 14 | kargopol
# Processing Record 20 of Set 14 | christchurch
# Processing Record 21 of Set 14 | cerbal
# City not found. Skipping...
# Processing Record 22 of Set 14 | kaeo
# Processing Record 23 of Set 14 | bani walid
# Processing Record 24 of Set 14 | port blair
# Processing Record 25 of Set 14 | kazanskaya
# Processing Record 26 of Set 14 | aklavik
# Processing Record 27 of Set 14 | cockburn town
# Processing Record 28 of Set 14 | south sioux city
# Processing Record 29 of Set 14 | whitehorse
# Processing Record 30 of Set 14 | billings
# Processing Record 31 of Set 14 | asyut
# Processing Record 32 of Set 14 | sidhauli
# Processing Record 33 of Set 14 | pasaje
# Processing Record 34 of Set 14 | kloulklubed
# Processing Record 35 of Set 14 | brownsville
# Processing Record 36 of Set 14 | portland
# Processing Record 37 of Set 14 | quatre cocos
# Processing Record 38 of Set 14 | ye
# City not found. Skipping...
# Processing Record 39 of Set 14 | beitbridge
# Processing Record 40 of Set 14 | erzin
# Processing Record 41 of Set 14 | porto belo
# Processing Record 42 of Set 14 | avenal
# Processing Record 43 of Set 14 | tazovskiy
# Processing Record 44 of Set 14 | sungaipenuh
# Processing Record 45 of Set 14 | pacific grove
# Processing Record 46 of Set 14 | carutapera
# Processing Record 47 of Set 14 | xichang
# Processing Record 48 of Set 14 | saint-joseph
# Processing Record 49 of Set 14 | clonakilty
# Processing Record 50 of Set 14 | sant feliu de guixols
# Processing Record 1 of Set 15 | tondano
# Processing Record 2 of Set 15 | amapa
# Processing Record 3 of Set 15 | san vicente
# Processing Record 4 of Set 15 | katima mulilo
# Processing Record 5 of Set 15 | kouango
# Processing Record 6 of Set 15 | samana
# Processing Record 7 of Set 15 | bathsheba
# Processing Record 8 of Set 15 | havoysund
# Processing Record 9 of Set 15 | prieska
# Processing Record 10 of Set 15 | xining
# Processing Record 11 of Set 15 | mitsamiouli
# Processing Record 12 of Set 15 | imbituba
# Processing Record 13 of Set 15 | union
# Processing Record 14 of Set 15 | berdigestyakh
# Processing Record 15 of Set 15 | wanaka
# Processing Record 16 of Set 15 | tautira
# Processing Record 17 of Set 15 | guia de isora
# Processing Record 18 of Set 15 | qaqortoq
# Processing Record 19 of Set 15 | phrae
# Processing Record 20 of Set 15 | birin
# Processing Record 21 of Set 15 | ritchie
# Processing Record 22 of Set 15 | fremont
# Processing Record 23 of Set 15 | puerto escondido
# Processing Record 24 of Set 15 | ovruch
# Processing Record 25 of Set 15 | rognan
# Processing Record 26 of Set 15 | oswego
# Processing Record 27 of Set 15 | ilebo
# Processing Record 28 of Set 15 | niamey
# Processing Record 29 of Set 15 | bonthe
# Processing Record 30 of Set 15 | makat
# Processing Record 31 of Set 15 | wencheng
# Processing Record 32 of Set 15 | sunrise manor
# Processing Record 33 of Set 15 | trabzon
# Processing Record 34 of Set 15 | paicandu
# Processing Record 35 of Set 15 | tromso
# Processing Record 36 of Set 15 | karangampel
# Processing Record 37 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 15 | oranjemund
# Processing Record 40 of Set 15 | thinadhoo
# Processing Record 41 of Set 15 | talesh
# City not found. Skipping...
# Processing Record 42 of Set 15 | tshikapa
# Processing Record 43 of Set 15 | pangody
# Processing Record 44 of Set 15 | belmonte
# Processing Record 45 of Set 15 | mayumba
# Processing Record 46 of Set 15 | maibong
# Processing Record 47 of Set 15 | indian head
# Processing Record 48 of Set 15 | alamogordo
# Processing Record 49 of Set 15 | najran
# Processing Record 50 of Set 15 | harnosand
# Processing Record 1 of Set 16 | santiago del estero
# Processing Record 2 of Set 16 | north bend
# Processing Record 3 of Set 16 | cayenne
# Processing Record 4 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 16 | koslan
# Processing Record 6 of Set 16 | matamoros
# Processing Record 7 of Set 16 | weinan
# Processing Record 8 of Set 16 | norrtalje
# Processing Record 9 of Set 16 | olga
# Processing Record 10 of Set 16 | hope
# Processing Record 11 of Set 16 | huarmey
# Processing Record 12 of Set 16 | erenhot
# Processing Record 13 of Set 16 | hamada
# Processing Record 14 of Set 16 | kandrian
# Processing Record 15 of Set 16 | delta del tigre
# Processing Record 16 of Set 16 | kasongo
# Processing Record 17 of Set 16 | mayo
# Processing Record 18 of Set 16 | darab
# Processing Record 19 of Set 16 | ust-nera
# Processing Record 20 of Set 16 | ojinaga
# Processing Record 21 of Set 16 | dzhebariki-khaya
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 717

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Turbat      PK  26.0023   63.0440     89.58        48          92
# 1     Ushuaia      AR -54.8000  -68.3000     42.46        49          20
# 2     Sambava      MG -14.2667   50.1667     67.82        85           7
# 3       Kenai      US  60.5544 -151.2583     45.03        57          75
# 4  Nouadhibou      MR  20.9310  -17.0347     71.58        88          59
# 5        Hilo      US  19.7297 -155.0900     81.28        89          90
# 6       Vaini      TO -21.2000 -175.2000     75.36        88          75
# 7      Albany      US  42.6001  -73.9662     50.36        94          99
# 8   Busselton      AU -33.6500  115.3333     60.04        80         100
# 9      Castro      BR -24.7911  -50.0119     56.34        96          21
#
#    Wind Speed      Description
# 0        5.37  overcast clouds
# 1       18.41       few clouds
# 2        8.48        clear sky
# 3       23.02    broken clouds
# 4       13.80    broken clouds
# 5        5.75       light rain
# 6        9.22       light rain
# 7        4.21  overcast clouds
# 8       13.15       light rain
# 9        5.12       few clouds

# %%
# Create CSV file from the DataFrame
output_data_file="WeatherPy_Database.csv"
# Export the city_data into a CSV
city_data_df.to_csv(output_data_file)
